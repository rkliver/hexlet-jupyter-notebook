# %% [markdown]
# # Решение аналитической задачи с помощью Jupyter Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv('C:\\Users\Roman\Documents\Hexlet\customer_shopping_data.csv')
df.set_index("customer_id", inplace=True)

df = df[['gender', 'age', 'price']]
female_df = df[df.gender == "Female"].groupby(["age"]).sum("price")

female_df.plot()
# Out:
# <Axes: xlabel='age'>
